# %%
import ast
import pandas as pd
import glob

# %% [markdown]
# The script below took 10 hours, do not run again!

# %%
def load_file_to_df(file_path):
    records = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f, 1):
            line = line.strip()
            if not line:
                continue  # skip empty lines
            try:
                # Convert the string representation to a dict
                record = ast.literal_eval(line)
                records.append(record)
            except Exception as e:
                print(f"Error processing line {i} in {file_path}: {e}")
    # Use json_normalize to flatten nested dictionaries
    df = pd.json_normalize(records)
    return df

# I really should have shoved them into a single folder, but I can't be bothered to move them now - V
# Glob Glob Glob
all_files = glob.glob('../../Data/Raw/*.txt')  
dataframes = [load_file_to_df(file) for file in all_files if 'unique_songs' not in file]

# Combine all DataFrames into one
df_all = pd.concat(dataframes, ignore_index=True)

print(df_all.head())
df_all.describe(include='all')
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit                                               href  \
# 0       151646     False  https://api.spotify.com/v1/tracks/50zAEIE4B1Qq...
# 1       200040     False  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 2       141805      True  https://api.spotify.com/v1/tracks/567e29TDzLwZ...
# 3       167303     False  https://api.spotify.com/v1/tracks/4Dvkj6JhhA12...
# 4       238805     False  https://api.spotify.com/v1/tracks/3USxtqRwSYz5...
#
#                        id  is_local  is_playable                       name  \
# 0  50zAEIE4B1QqhPjRMK2Xmh     False         True               Running Wild
# 1  0VjIjW4GlUZAMYd2vXMi3b     False         True            Blinding Lights
# 2  567e29TDzLwZwfDuEpGTwo     False         True  STAY (with Justin Bieber)
# 3  4Dvkj6JhhA12EX05fT7y2e     False         True                  As It Was
# 4  3USxtqRwSYz57Ewm6wWRMp     False         True                 Heat Waves
#
#    ...                                       album.images album.is_playable  \
# 0  ...  [{'height': 640, 'width': 640, 'url': 'https:/...              True
# 1  ...  [{'height': 640, 'width': 640, 'url': 'https:/...              True
# 2  ...  [{'height': 640, 'width': 640, 'url': 'https:/...              True
# 3  ...  [{'height': 640, 'width': 640, 'url': 'https:/...              True
# 4  ...  [{'height': 640, 'width': 640, 'url': 'https:/...              True
#
#                album.name album.release_date album.release_date_precision  \
# 0   Happy - :') (Remixes)         2024-11-19                          day
# 1             After Hours         2020-03-20                          day
# 2  F*CK LOVE 3+: OVER YOU         2021-07-27                          day
# 3           Harry's House         2022-05-20                          day
# 4               Dreamland         2020-08-07                          day
#
#   album.total_tracks album.type                             album.uri  \
# 0                  8      album  spotify:album:3nRmQ70bczWCLWyj1aRbt6
# 1                 14      album  spotify:album:4yP0hdKOZPNshxUOjY0cZj
# 2                 35      album  spotify:album:576UTio7xgY7YUxrHMzxeI
# 3                 13      album  spotify:album:5r36AJ6VOJtp00oxSkBZ5h
# 4                 16      album  spotify:album:5bfpRtBW7RNRdsm3tRyl3R
#
#   external_ids.isrc                              external_urls.spotify
# 0      USA2P2461990  https://open.spotify.com/track/50zAEIE4B1QqhPj...
# 1      USUG11904206  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# 2      USSM12103949  https://open.spotify.com/track/567e29TDzLwZwfD...
# 3      USSM12200612  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 4      GBUM72000433  https://open.spotify.com/track/3USxtqRwSYz57Ew...
#
# [5 rows x 31 columns]
#                                                   artists  \
# count                                              199908
# unique                                              87221
# top     [{'external_urls': {'spotify': 'https://open.s...
# freq                                                  513
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                         available_markets    disc_number  \
# count                                              199908  199908.000000
# unique                                               2998            NaN
# top     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            NaN
# freq                                               123082            NaN
# mean                                                  NaN       1.011890
# std                                                   NaN       0.153801
# min                                                   NaN       1.000000
# 25%                                                   NaN       1.000000
# 50%                                                   NaN       1.000000
# 75%                                                   NaN       1.000000
# max                                                   NaN      17.000000
#
#          duration_ms explicit  \
# count   1.999080e+05   199908
# unique           NaN        2
# top              NaN    False
# freq             NaN   137086
# mean    2.033899e+05      NaN
# std     9.099713e+04      NaN
# min     1.620000e+04      NaN
# 25%     1.667128e+05      NaN
# 50%     1.949515e+05      NaN
# 75%     2.277860e+05      NaN
# max     8.972714e+06      NaN
#
#                                                      href  \
# count                                              199908
# unique                                             189600
# top     https://api.spotify.com/v1/tracks/3IooKSGurp7b...
# freq                                                  203
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                             id is_local is_playable      name  ...  \
# count                   199908   199908      199908    199908  ...
# unique                  189600        1           2    164079  ...
# top     3IooKSGurp7bwCnK5odZEZ    False        True  Presence  ...
# freq                       203   199908      199907       203  ...
# mean                       NaN      NaN         NaN       NaN  ...
# std                        NaN      NaN         NaN       NaN  ...
# min                        NaN      NaN         NaN       NaN  ...
# 25%                        NaN      NaN         NaN       NaN  ...
# 50%                        NaN      NaN         NaN       NaN  ...
# 75%                        NaN      NaN         NaN       NaN  ...
# max                        NaN      NaN         NaN       NaN  ...
#
#                                              album.images album.is_playable  \
# count                                              199908            199908
# unique                                             112712                 1
# top     [{'height': 640, 'width': 640, 'url': 'https:/...              True
# freq                                                  203            199908
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#         album.name album.release_date album.release_date_precision  \
# count       199908             199908                       199908
# unique      102505               8965                            3
# top       Presence         2025-01-31                          day
# freq           213                596                       196530
# mean           NaN                NaN                          NaN
# std            NaN                NaN                          NaN
# min            NaN                NaN                          NaN
# 25%            NaN                NaN                          NaN
# 50%            NaN                NaN                          NaN
# 75%            NaN                NaN                          NaN
# max            NaN                NaN                          NaN
#
#        album.total_tracks album.type                             album.uri  \
# count       199908.000000     199908                                199908
# unique                NaN          1                                112709
# top                   NaN      album  spotify:album:37Izr0igRkZEUUto8T2OC6
# freq                  NaN     199908                                   203
# mean             9.753106        NaN                                   NaN
# std             10.584666        NaN                                   NaN
# min              1.000000        NaN                                   NaN
# 25%              1.000000        NaN                                   NaN
# 50%             10.000000        NaN                                   NaN
# 75%             14.000000        NaN                                   NaN
# max            930.000000        NaN                                   NaN
#
#        external_ids.isrc                              external_urls.spotify
# count             199880                                             199908
# unique            188935                                             189600
# top         SE69N2500014  https://open.spotify.com/track/3IooKSGurp7bwCn...
# freq                 203                                                203
# mean                 NaN                                                NaN
# std                  NaN                                                NaN
# min                  NaN                                                NaN
# 25%                  NaN                                                NaN
# 50%                  NaN                                                NaN
# 75%                  NaN                                                NaN
# max                  NaN                                                NaN
#
# [11 rows x 31 columns]

# %%
df_all.to_csv('../../Data/Raw/spotify_data_merged.csv', index=False)

# %%
df_all = pd.read_csv('../../Data/Raw/spotify_data_merged.csv')

# %%
pd.set_option('display.max_columns', None)
print(df_all.columns)
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'href', 'id', 'is_local', 'is_playable', 'name',
#        'popularity', 'preview_url', 'track_number', 'type', 'uri',
#        'album.album_type', 'album.artists', 'album.available_markets',
#        'album.external_urls.spotify', 'album.href', 'album.id', 'album.images',
#        'album.is_playable', 'album.name', 'album.release_date',
#        'album.release_date_precision', 'album.total_tracks', 'album.type',
#        'album.uri', 'external_ids.isrc', 'external_urls.spotify'],
#       dtype='object')

# %%
columns_to_keep = ['name', 'artists', 'album.name', 'duration_ms', 'popularity', 'id', 'external_ids.isrc', 'album.release_date_precision', 'album.release_date', 'album.total_tracks', 'disc_number', 'available_markets']
df_reduced = df_all[columns_to_keep]
print(df_reduced.head())
# Out:
#                         name  \
# 0               Running Wild
# 1            Blinding Lights
# 2  STAY (with Justin Bieber)
# 3                  As It Was
# 4                 Heat Waves
#
#                                              artists              album.name  \
# 0  [{'external_urls': {'spotify': 'https://open.s...   Happy - :') (Remixes)
# 1  [{'external_urls': {'spotify': 'https://open.s...             After Hours
# 2  [{'external_urls': {'spotify': 'https://open.s...  F*CK LOVE 3+: OVER YOU
# 3  [{'external_urls': {'spotify': 'https://open.s...           Harry's House
# 4  [{'external_urls': {'spotify': 'https://open.s...               Dreamland
#
#    duration_ms  popularity                      id external_ids.isrc  \
# 0       151646          80  50zAEIE4B1QqhPjRMK2Xmh      USA2P2461990
# 1       200040          89  0VjIjW4GlUZAMYd2vXMi3b      USUG11904206
# 2       141805          82  567e29TDzLwZwfDuEpGTwo      USSM12103949
# 3       167303          88  4Dvkj6JhhA12EX05fT7y2e      USSM12200612
# 4       238805          86  3USxtqRwSYz57Ewm6wWRMp      GBUM72000433
#
#   album.release_date_precision album.release_date  album.total_tracks  \
# 0                          day         2024-11-19                   8
# 1                          day         2020-03-20                  14
# 2                          day         2021-07-27                  35
# 3                          day         2022-05-20                  13
# 4                          day         2020-08-07                  16
#
#    disc_number                                  available_markets
# 0            1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 1            1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 2            1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 3            1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 4            1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...

# %% [markdown]
# Turns out that the describe alone takes 90 minutes??? like why?

# %%
df_reduced = df_reduced.drop_duplicates(subset='id', keep='first')
#print(df_reduced.describe(include='all'))

# %% [markdown]
# only 28 rows missing isrc

# %%
# Find the maximum number of items in the 'artists' column
max_artists_count = df_reduced['artists'].apply(lambda x: len(ast.literal_eval(x))).max()
print(f"The maximum number of items in the 'artists' column is: {max_artists_count}")
# Out:
# The maximum number of items in the 'artists' column is: 10

# %% [markdown]
# 10 artists for some songs? Do we want all of those?

# %%
# Extract the first few artist names from the 'artists' column
df_reduced['artist_1'] = df_reduced['artists'].apply(lambda x: ast.literal_eval(x)[0]['name'] if len(ast.literal_eval(x)) > 0 else None)
df_reduced['artist_2'] = df_reduced['artists'].apply(lambda x: ast.literal_eval(x)[1]['name'] if len(ast.literal_eval(x)) > 1 else None)
df_reduced['artist_3'] = df_reduced['artists'].apply(lambda x: ast.literal_eval(x)[2]['name'] if len(ast.literal_eval(x)) > 2 else None)
df_reduced['artist_4'] = df_reduced['artists'].apply(lambda x: ast.literal_eval(x)[3]['name'] if len(ast.literal_eval(x)) > 3 else None)

# Drop the original 'artists' column (not for now, only once I'm fully sure how many artists we want to keep)
df_reduced = df_reduced.drop(columns=['artists'])

print(df_reduced[['artist_1', 'artist_2', 'artist_3', 'artist_4']].head())
# Out:
#         artist_1       artist_2 artist_3 artist_4
# 0            Jin           None     None     None
# 1     The Weeknd           None     None     None
# 2  The Kid LAROI  Justin Bieber     None     None
# 3   Harry Styles           None     None     None
# 4  Glass Animals           None     None     None

# %%
print(df_reduced[['artist_1', 'artist_2', 'artist_3', 'artist_4']].describe(include='all'))
# Out:
#             artist_1            artist_2       artist_3       artist_4
# count         189600               68848          20978           6935
# unique         38231               24165          10953           4674
# top     Die drei ???  Hver gang vi møtes  Ty Dolla $ign  Maite Perroni
# freq             499                 153             43             32

# %%
df_reduced.to_csv('../../Data/Processed/spotify_data.csv', index=False)
